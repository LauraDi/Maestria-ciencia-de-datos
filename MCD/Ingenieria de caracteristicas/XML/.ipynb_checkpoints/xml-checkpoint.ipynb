# %% [markdown]
# <center>
# <p><img src="https://mcd.unison.mx/wp-content/themes/awaken/img/logo_mcd.png" width="150">
# </p>
#
#
#
# <h1>Curso Ingeniería de Características</h1>
#
# <h3> Dr. Julio Waissman Vilanova </h3>
#
# <h3>Descargando datos en XML</h3>
#
# <h2> Alumna: Diana Laura Ballesteros Valenzuela</h2>
#
# <p>
# <img src="https://identidadbuho.unison.mx/wp-content/uploads/2019/06/letragrama-cmyk-72.jpg" width="150">
# </p>
#
#
# </center>

# %%
import re
import pandas as pd
import requests
import xml.dom.minidom
import numpy as np
import xml.etree.cElementTree as et
from inspect import getmembers , isclass , isfunction

# %%
XML= "https://raw.githubusercontent.com/mcd-unison/ing-caract/main/ejemplos/integracion/ejemplos/wikipedia-poetas.xml"

# %%
response = requests.get(XML)

with open('poetas.xml', 'wb') as file:
    file.write(response.content)
    
dom = xml.dom.minidom.parse("./poetas.xml") 
pretty = dom.toprettyxml()

# %%
tree=et.parse('./poetas.xml') #Leemos archivo
root=tree.getroot()

# %%
author_list = []
text_list = []

for autor in root.findall('{http://www.mediawiki.org/xml/export-0.10/}page'):
    title =  autor.find('{http://www.mediawiki.org/xml/export-0.10/}title')
    revision =  autor.find('{http://www.mediawiki.org/xml/export-0.10/}revision')
    texto = revision.find('{http://www.mediawiki.org/xml/export-0.10/}text')
    
    author_list.append(title.text)
    text_list.append(texto.text)

# %%
df_author = pd.DataFrame(author_list) #Dataframe para autores
df_author.columns = ['Autor']

df_text = pd.DataFrame(text_list) #dataframe para texto
df_text.columns = ['Texto']

df = pd.concat([df_author, df_text], axis=1, join='inner')

# %%
novela = []

for text in df['Texto']: # Filtrar cada obra
    novela_found = re.findall("(==\s*Novela\w*\s*==)(.*?)(\n==)", text, flags = re.DOTALL)
    novela.append(novela_found)
novela
# Out:
# [[],
#  [],
#  [],
#  [('== Novelas ==',
#    "=\n* 1980 - ''Soy paciente'', Losada, Buenos Aires (reeditada en 1996 por Altaya, Buenos Aires, y Sudamericana, Buenos Aires)\n* 1984 - ''Los amores de Laurita'', Sudamericana, Buenos Aires (reeditada por Emecé Editores, Buenos Aires, 2006)\n* 1994 - ''El libro de los recuerdos'', Sudamericana, Buenos Aires\n* 1997 - ''[[La muerte como efecto secundario]]'', Sudamericana. Buenos Aires\n* 2007 - ''El peso de la tentación'', Emecé Editores, Buenos Aires\n* 2016 - ''Hija'', Emecé Editores, Buenos Aires\n",
#    '\n==')],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [('== Novelas ==',
#    "=\n\n* ''Hay que sonreír''. Novela. Buenos Aires: Editorial Americalee, 1966. (CD-Rom: Buenos Aires, Ediciones La Margarita Digital, 2004).\n* ''El gato eficaz''. Novela. México: Ediciones Joaquín Mortíz, 1972. (Otras ediciones: Buenos Aires: Ediciones de la Flor, 1991, 2001).\n* ''Como en la guerra''. Novela. Buenos Aires: Sudamericana, 1977. (Otras ediciones: La Habana: Ediciones Casa de las Américas, 2001).\n* ''Cola de lagartija''. Novela. Buenos Aires: Editorial Bruguera, 1983. (Ot
#    '\n==')],
#  [],
#  [],
#  [('== Novela ==',
#    '=\n\n1. \'\'El mendigo de San Ángel. Novela histórica original,\'\' (primera edición), 1852, se ignora la imprenta o editorial. cfr. Andrés Lira, "La prensa periódica y la historiografía mexicana del siglo XIX" en Aurora Cano Andaluz (coordinadora), Las publicaciones periódicas y la historia de México (ciclo de conferencias), UNAM, 1995, p. 9.\n\'\'El mendigo de San Ángel. Novela histórica original,\'\' (segunda edición), Imprenta Literaria, México, (1864-1865)\n\n2. \'\'Un ángel desterrado del cielo. Leyenda religiosa\'\', Imprenta de V. Segura, México, 1855.\t\n\n3. \'\'El buscador de oro en California\'\', Tomás S. Gardida, México, 1855\t\n\n4. \'\'El jarabe. Obra de costumbres mexicanas, jocosa, simpática, burlesca, satírica y de carcajadas, escrita para desterrar el mal humor, herencia que nos legó nuestro padre Adán por un necio antojo que quiso satisfacer\'\', (primera edición), Imprenta de V. Segura, México, 1860\t\n\'\'El jarabe. Obra de costumbres mexicanas, jocosa, simpática, burlesca, satírica y de carcajadas, escrita para desterrar el mal humor, herencia que nos legó nuestro padre Adán por un necio antojo que quiso satisfacer\'\', (segunda edición), Imprenta de L. Inclán, México, 1861\t\n\n5. \'\'El capitán Rossi. Novela histórica original\'\', Imprenta Literaria, México, 1864.\n\n6. \'\'La destrucción de Pompeya\'\', Imprenta de Cumplido, 1871.\n',
#    '\n==')],
#  [],
#  [('== Novelas ==',
#    "=\n*''Mexican Village''. 8ª edición de Northwestern University Press, 893 pp. ISBN 0810123401, ISBN 9780810123403 [http://books.google.com.ar/books?id=ATEHE4ybEJYC&printsec=frontcover&dq=%22Josefina+Niggli%22&hl=es&sa=X&ei=aQnkUZ2qHsOniAK52IC4BA&ved=0CC4Q6AEwAA#v=onepage&q=%22Josefina%20Niggli%22&f=false en línea]\n\n*''Step Down, Elder Brother''. Editor Rinehart, 374 pp. 1947\n\n*''A Miracle for Mexico''\n",
#    '\n==')],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [('==Novela==',
#    "=\n\n* ''House: retratos desarmables'' (Zeta, 2011)\n* ''Narvarte pesadilla'' (Editorial MoHo, 2017). Edición póstuma.\n",
#    '\n==')],
#  [],
#  [('== Novela ==',
#    "==\n* ''Morirás lejos'' (1967)\n* ''[[Las batallas en el desierto]]'' (1981)\n",
#    '\n==')],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [('== Novela ==',
#    "=\n* ''Lejos del paraíso'' (Sansores y Aljure, 1997)\n* ''Los hermanos Pastor en la Corte de Moctezuma''  (Colibrí, 2003).\n",
#    '\n==')],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [('== Novela ==',
#    "=\n* ''Las sirenas sueñan con trilobites.'' Ediciones SM (2011)\n* ''Frecuencia Júpiter.'' Ediciones SM (2013)\n* ''Buenas noches, Laika''. Fondo de Cultura Económica (2014) \n* ''Ella trae la lluvia''. Ilustrado por Roger Ycaza. Ediciones El Naranjo (2016)\n",
#    '\n==')],
#  [],
#  [],
#  [],
#  [],
#  [('== Novelas ==',
#    "=\n* ''Los extraños de la planta baja'' (Ediciones Desde Abajo, Bogotá, Colombia, 2015, 172 pp. ISBN 9789585882683)\n* ''Al paso de los días'' (Editorial Terracota, Ciudad de México, 2013, 174 pp. ISBN 9786077130895)\n* ''Marcha seca'' (Ediciones Era, México, 1999, 76 pp. ISBN 9684114540)\n* ''La decisión del capitán'' (Ediciones Era, México, 1997, 181 pp. ISBN 9684114133)\n* ''Los pescadores del Kukulkán'' (Aldus, México, 1995, 67 pp. ISBN 9686830413)\n* ''Estar en el mundo'' (1994, Ediciones Era, México, 135 pp. ISBN 9684113579. Traducida al alemán como: Schwestern, en 1996, publicada por Eichborn, Frankfurt, y en 1998 en edición de bolsillo por la editorial Piper, Frankfurt)\n* ''Manantial de dos fuentes'' (Instituto Michoacano de Cultura, Morelia, México, 1994, 122 pp.)\n* ''Calla mi amor que vivo'' (Ediciones Era, México, 1990, 147 pp. ISBN 9684113277)\n* ''Días sin Casura'' (Leega Literaria, México, 1986, 90 pp. ISBN 9684950357. Edición digital de Ars Longa, México, 2011, ISBN digital: 6326)\n",
#    '\n==')],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [('== Novela ==', "=\n* ''Zarandona'' (2000)\n", '\n==')],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [('== Novela ==',
#    "=\n* ''Cuando las panteras no eran negras'' (Siruela, 1997; FCE, 2010), novela infantil ganadora del premio internacional ''White Raven'' en 1997.\n* ''Emilio, los chistes y la muerte'' (Anagrama, 2009).\n",
#    '\n==')],
#  [],
#  [('==Novela==', "=\n* ''Sobre esta piedra'' (1981)\n", '\n==')],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [('== Novela ==',
#    "=\n* ''Figuraciones en el fuego'' (1980) \n* ''Solo la ciudad es real'' (1982)\n",
#    '\n==')],
#  [('== Novela ==',
#    "=\n* ''Los cuerpos abandonados en el vacío'' (1974) \n* ''Semejanza del juego'' (1989)\n* ''Descaro de la máscara'' (1997)\n* ''Rosa blanda'' (2009)\n",
#    '\n==')],
#  [('== Novela ==',
#    "=\n* ''La isla en el lago'' (1994)\n* ''El diario de la Riva'' (2001)\n",
#    '\n==')],
#  [('== Novela ==',
#    "=\n* ''Los cuervos'' (2006)\n* ''Una isla sin mar'' (2009)\n* ''Juárez Whiskey'' (2013)\n* ''La balada de los arcos dorados'' (2014)\n",
#    '\n==')],
#  [],
#  [('== Novela ==',
#    "=\n* ''Neon city blues. La muerte de Vicky M. Doodle'' (2001)\n",
#    '\n==')],
#  [],
#  [],
#  [('== Novela ==', "=\n* ''La creciente'' (1979)\n", '\n==')],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [('== Novela ==',
#    "=\n* ''La resurrección de Clotilde Goñi'' (1976)\n* ''Refugio'' (1996)\n",
#    '\n==')],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [('== Novelas ==',
#    "=\n* ''Carne Viva'' (1943)\n* ''Tierra seca'' (1945)\n* ''Poza negra (1''960) novela histórica sobre Poza Rica\n* ''Cruz Roja (''1963)\n* ''Amores'' ''en tierra de sangre y sol (''1964),  novela corta\n",
#    '\n==')],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [('== Novela ==',
#    "=\n* ''Xtille Zikw Belé, lhén been nhálhje ke Yu’Bza’o/Pancho Culebro y los naguales de Tierra Azul'' (2008)\n",
#    '\n==')],
#  [],
#  [],
#  []]

# %%
dfNovela = pd.DataFrame(novela)
dfNovela.columns = ['Novela']
dfNovela 

df = pd.concat([df, dfNovela], axis=1, join='inner') 
df.to_parquet('poetas_df.parquet')  #dataframe con obra de cada autor
